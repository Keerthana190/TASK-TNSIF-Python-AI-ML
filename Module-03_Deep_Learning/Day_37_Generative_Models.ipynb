# %% [markdown]
# #Generative AI?
# Definition
#
# Generative AI is a branch of Artificial Intelligence that learns patterns from existing data and creates new content such as text, images, videos, music, code, and speech.
#
# Unlike traditional AI, which mainly predicts or classifies, Generative AI can generate entirely new data that resembles what it has learned.
#
# Simple Definition
#
# Generative AI is an AI technology that learns from existing data and creates new content similar to human-created content.
#
# #Real-Life Examples
#
# | Input                  | Output                 |
# | ---------------------- | ---------------------- |
# | "Write a leave letter" | Complete leave letter  |
# | "Generate a cat image" | AI-generated cat image |
# | "Write Python code"    | Python program         |
# | "Compose a song"       | AI-generated music     |
#
# #Traditional AI vs Generative AI
# | Traditional AI     | Generative AI          |
# | ------------------ | ---------------------- |
# | Predicts           | Creates                |
# | Classification     | Content Generation     |
# | Spam Detection     | Email Writing          |
# | Fraud Detection    | Story Generation       |
# | Disease Prediction | Medical Report Writing |
#
# #Applications
# - Chatbots
# - Image Generation
# - Video Creation
# - Music Generation
# - Code Generation
# - Content Writing
# - Drug Discovery
# - Game Design

# %% [markdown]
# #How Generative AI Works
# Training Data
#
#       │
#       ▼
# Learn Patterns
#
#       │
#       ▼
# Deep Learning Model
#
#       │
#       ▼
# User Prompt
#
#       │
#       ▼
# Generate New Content

# %% [markdown]
# #Overview of Generative Models
#
# Generative AI uses several deep learning architectures to generate different types of content.
#
# The three most important are:
#
# 1. GANs (Generative Adversarial Networks)
# 2. VAEs (Variational Autoencoders)
# 3. LLMs (Large Language Models)
#
# | Model | Full Form                      | Mainly Used For                        |
# | ----- | ------------------------------ | -------------------------------------- |
# | GAN   | Generative Adversarial Network | Image Generation                       |
# | VAE   | Variational Autoencoder        | Image Reconstruction & Data Generation |
# | LLM   | Large Language Model           | Text Generation                        |
#
# #Simple Workflow
#                Generative Models
#
#           ┌─────────────┐
#           │     GAN     │
#           └──────┬──────┘
#                  │
#          Creates realistic images
#
#           ┌─────────────┐
#           │     VAE     │
#           └──────┬──────┘
#                  │
#       Learns compressed features
#
#           ┌─────────────┐
#           │     LLM     │
#           └──────┬──────┘
#                  │
#         Generates human language
#
# #Generative Adversarial Networks (GANs)
# Definition
#
# A GAN is a deep learning model consisting of two neural networks that compete with each other to generate realistic data.
#
# Introduced by Ian Goodfellow (2014).
#
# Two Networks
# 1. Generator (G)
#
# Creates fake images from random noise.
#
# Goal:
#
# Fool the discriminator.
#
# 2. Discriminator (D)
#
# Checks whether an image is real or fake.
#
# Goal:
#
# Detect fake images.
#
# #Workflow
# Random Noise
#
#       │
#       ▼
#  Generator
#
#       │
# Fake Image
#
#       │
#       ▼
# Discriminator
#
#    │
#
#
# Real?    Fake?

# %% [markdown]
# #Training Process
# Step 1
#
# Generator creates fake images.
#
# ↓
#
# Step 2
#
# Discriminator compares them with real images.
#
# ↓
#
# Step 3
#
# Discriminator gives feedback.
#
# ↓
#
# Step 4
#
# Generator improves.
#
# ↓
#
# Repeat thousands of times.
#
# Eventually:
#
# Generator creates highly realistic images.
#
# #Real-Life Example
#
# Imagine a student drawing fake currency.
#
# Teacher checks whether it looks real.
#
# Teacher points out mistakes.
#
# Student improves.
#
# Eventually the fake currency looks almost real.
#
# Generator = Student
#
# Discriminator = Teacher
#
# #Applications
# Face Generation,
#
# Deepfake Images
#
# Art Creation
#
# Fashion Design
#
# Super Resolution
#
# Data Augmentation
# #Advantages
#
# ✔ High-quality images
#
# ✔ Realistic outputs
#
# ✔ Excellent for image synthesis
#
# Disadvantages
#
# ✘ Difficult to train
#
# ✘ Mode collapse
#
# ✘ Requires lots of computation

# %% [markdown]
# #Variational Autoencoders (VAEs)
# Definition
#
# A Variational Autoencoder (VAE) is a generative model that learns a compressed representation (latent space) of data and then reconstructs or generates new similar data.
#
# Unlike GANs, VAEs focus on learning the underlying distribution of the data.
#
# #Components
# Encoder
#
# Compresses the input into a latent representation.
#
# ↓
#
# Latent Space
#
# Stores important features in a compact form.
#
# ↓
#
# Decoder
#
# Reconstructs the original data or creates new samples.
#
# #Workflow
# Input Image
#       │
#       ▼
#  Encoder
#       │
# Latent Space
#       │
#       ▼
#  Decoder
#       │
# Reconstructed Image
#
# #Real-Life Example
#
# Think of compressing a photo into a ZIP file.
#
# Encoder → Compress
#
# Latent Space → ZIP file
#
# Decoder → Restore photo
#
# #Applications
# Face Generation
#
# Image Denoising
#
# Data Compression
#
# Missing Image Reconstruction
#
# Medical Imaging
#
# #Advantages
#
# ✔ Stable training
#
# ✔ Learns meaningful representations
#
# ✔ Good for anomaly detection
#
# #Disadvantages
#
# ✘ Images may appear blurry
#
# ✘ Less realistic than GANs
#
# #GAN vs VAE
#
# | Feature          | GAN        | VAE             |
# | ---------------- | ---------- | --------------- |
# | Quality          | Excellent  | Moderate        |
# | Training         | Difficult  | Easier          |
# | Output           | Very Sharp | Slightly Blurry |
# | Speed            | Slow       | Faster          |
# | Image Generation | Excellent  | Good            |

# %% [markdown]
# #Image Synthesis with GANs
# What is Image Synthesis?
#
# Image synthesis means creating entirely new images using AI.
#
# GANs are one of the most powerful techniques for this task.
#
# #Workflow
#
# Random Noise
#       │
#       ▼
# Generator
#       │
# Artificial Image
#       │
#       ▼
# Looks Like Real Image
#
# #Examples
#
# Generate:
#
# Human Faces,
# Cats,
# Dogs,
# Cars,
# Buildings,
# Paintings,
# Anime Characters.
#
# #Real-Life Applications
#
# | Industry      | Application              |
# | ------------- | ------------------------ |
# | Entertainment | Movie Characters         |
# | Gaming        | Game Assets              |
# | Fashion       | Clothing Design          |
# | Healthcare    | Medical Image Generation |
# | Architecture  | Building Designs         |

# %% [markdown]
# #Text Generation with GPT
# What is GPT?
#
# GPT (Generative Pre-trained Transformer) is a Large Language Model (LLM) developed by OpenAI that generates human-like text.
#
# GPT is based on the Transformer architecture, which uses an attention mechanism to understand relationships between words in a sequence.
#
# How GPT Works
# Step 1
#
# Pre-training
#
# Learns from billions of words.
#
# ↓
#
# Step 2
#
# User enters a prompt.
#
# ↓
#
# Step 3
#
# GPT predicts the next most likely token (word or subword).
#
# ↓
#
# Step 4
#
# Repeats the prediction until the response is complete.
#
# #workflow
# Books
# Articles
# Code
# Websites
#
#       │
#       ▼
# Pre-training
#
#       │
#       ▼
# GPT Model
#
#       │
# User Prompt
#
#       │
#       ▼
# Generated Response
#
# #Example
#
# - Prompt
#
# Write a motivational quote.
#
# - Output
#
# Success is built one small step at a time. Keep learning, stay consistent, and never stop growing.
#
# #Applications
# Chatbots
# Email Writing
# Code Generation
# Translation
# Story Writing
# Summarization
# Question Answering
# Content Creation
# #Advantages
#
# ✔ Understands natural language
#
# ✔ Generates fluent text
#
# ✔ Supports many languages
#
# ✔ Assists with coding and writing
#
# #Limitations
#
# ✘ Can generate incorrect information (hallucinations)
#
# ✘ Depends on prompt quality
#
# ✘ May reflect biases in training data
#
# ✘ Requires significant computational resources

# %% [markdown]
# Generative AI
# │
# ├── Creates New Content
# │
# ├── Generative Models
# │     ├── GAN
# │     ├── VAE
# │     └── LLM (GPT)
# │
# ├── GAN
# │     ├── Generator
# │     ├── Discriminator
# │     └── Image Generation
# │
# ├── VAE
# │     ├── Encoder
# │     ├── Latent Space
# │     └── Decoder
# │
# └── GPT
#       ├── Transformer-based LLM
#       ├── Text Generation
#       └── Prompt → Response

# %% [markdown]
# #Interview Questions
# What is Generative AI?
# How is Generative AI different from Traditional AI?
# What are the three major generative models?
# What is a GAN, and why does it use two networks?
# Explain the roles of the Generator and Discriminator.
# What is a Variational Autoencoder (VAE)?
# Compare GANs and VAEs.
# What is image synthesis?
# What does GPT stand for, and what is it used for?
# How does GPT generate text?
# What are some real-world applications of Generative AI?
# What are the advantages and limitations of GPT?

# %% [markdown]
# # Types of Content Generated by Generative AI
#
# Generative AI can create many different types of content.
#
# | Content Type | Example |
# |--------------|----------|
# | Text | Stories, Emails, Blogs |
# | Images | AI Art, Logos |
# | Videos | AI Videos |
# | Audio | Music, Voice Cloning |
# | Code | Python, Java, HTML |
# | 3D Models | Game Characters |
#
# # Popular Generative AI Tools
#
# | Tool | Purpose |
# |------|---------|
# | ChatGPT | Text Generation |
# | Gemini | AI Assistant |
# | Claude | Writing & Coding |
# | GitHub Copilot | Code Generation |
# | Midjourney | AI Images |
# | DALL·E | Image Generation |
# | Stable Diffusion | Image Generation |
# | Runway ML | AI Video Generation |
#
# # Generative AI vs Discriminative AI
#
# | Generative AI | Discriminative AI |
# |---------------|-------------------|
# | Creates new data | Predicts labels |
# | Learns data distribution | Learns decision boundary |
# | Generates images | Image Classification |
# | Generates text | Spam Detection |
# | Examples: GPT, GAN, VAE | CNN, Logistic Regression, SVM |
#
# # How ChatGPT Works
#
# User Prompt
#
# ↓
#
# Tokenizer
#
# ↓
#
# Transformer
#
# ↓
#
# Attention Mechanism
#
# ↓
#
# Large Language Model
#
# ↓
#
# Generated Response
#
# # Industries Using Generative AI
#
# Healthcare
#
# Finance
#
# Education
#
# Entertainment
#
# Gaming
#
# Marketing
#
# Cybersecurity
#
# Software Development
#
# Architecture
#
# Fashion Design
#
# # Future Scope
#
# Generative AI is expected to transform many industries by enabling:
#
# - Personalized education
# - AI software development
# - Drug discovery
# - Robotics
# - Autonomous systems
# - Intelligent assistants
# - Scientific research

# %% [markdown]
# ###Practice Example
#
# Prompt → AI-generated text

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "Artificial Intelligence is"

result = generator(prompt, max_length=40, num_return_sequences=1)

print(result[0]["generated_text"])
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...
