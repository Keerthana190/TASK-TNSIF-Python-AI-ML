# %% [markdown]
# # Day-01: Introduction to Python
#
# ## Objective
# Learn the fundamentals of Python programming including variables, identifiers, keywords, comments, and input/output.
#
# ## Topics Covered
# - Introduction to Python
# - Features of Python
# - Variables
# - Identifiers
# - Keywords
# - Comments
# - Input and Output

# %%
#Simple Code Examples
print("Hello World")
# Out:
# Hello World

# %%
print("Hello Keerthana!")
print("Welcome to Python world")
# Out:
# Hello Keerthana!
# Welcome to Python world

# %%
#Variables

name = "Keerthana"
age = 22
cgpa = 8.6

print(name)
print(age)
print(cgpa)
# Out:
# Keerthana
# 22
# 8.6

# %%
#Data Types

a = 10
b = 10.5
c = True
d = "Python"

print(type(a))
print(type(b))
print(type(c))
print(type(d))


p = 20
q = 2.5
r = False
s = 'AI & ML'

print(p,q,r,s)
print(type(p))
print(type(q))
print(type(r))
print(type(s))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# 20 2.5 False AI & ML
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
#Input

name = input("Enter your name: ")

print("Welcome", name)
# Out:
# Enter your name: Sirikonda Keerthana
# Welcome Sirikonda Keerthana

# %%
# Comments
# This is a single line comment

"""
This is a
multi-line comment
"""
# Out:
# '\nThis is a\nmulti-line comment\n'

# %%
#Keywords

import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Identifiers

student_name = "Ravi"

print(student_name)
# Out:
# Ravi

# %%
#Multiple Assignment

a, b, c = 10, 20, 30

print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
#Swapping

a = 10
b = 20

a, b = b, a

print(a)
print(b)
# Out:
# 20
# 10
